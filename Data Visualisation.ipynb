# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as s
import numpy as n

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
dataset_df = pd.read_excel('C:\\Users\\admin\\OneDrive\\Desktop\\Dissertation\\Consolidated Data.xlsx')

# %%
df=dataset_df.dropna()

# %%
df.columns
# Out:
# Index(['YEAR', 'AUTHORISATION_ID ', 'OPERATOR_NAME', 'SITE_ADDRESS',
#        'SITE_POSTCODE', 'EA_AREA_NAME', 'ROUTE_NAME', 'SUBSTANCE_NAME',
#        'REPORTING_THRESHOLD_(kg)', 'QUANTITY_RELEASED_(kg)',
#        'ABOVE_THRESHOLD_(kg)', 'REGULATED_INDUSTRY_SECTOR',
#        'REGULATED_INDUSTRY_SUB_SECTOR'],
#       dtype='object')

# %%
df["SUBSTANCE_NAME"].unique()
# Out:
# array(['Benzo(a)pyrene', 'Benzo(b)fluoranthene',
#        'Octylphenols and octylphenol ethoxylates',
#        'Chloroform (Trichloromethane)', 'Trifluralin',
#        'Carbon tetrachloride (Tetrachloromethane)', 'Carbon dioxide',
#        'Dichloromethane (DCM) (Methylene chloride)',
#        'Organotin compounds - as Sn', 'Phenols - total as C', 'Lead',
#        'Dioxins and furans (PCDDs/PCDFs) - as WHO TEQ',
#        'Dioxins and furans (PCDDs/PCDFs) - as ITEQ', 'Ammonia',
#        'Brominated diphenylethers - penta-, octa- and deca- BDE',
#        'Chlorides - as Cl', 'Methane',
#        'Nonylphenols and nonylphenol ethoxylates', 'Naphthalene',
#        'Tributyltin and compounds - as TBT', 'Mercury', 'Nickel',
#        'Cyanides - as CN', 'Fluorides - as F', 'Zinc',
#        'Di(2-ethylhexyl)phthalate (DEHP)', 'Diuron',
#        'Halogenated organic compounds - as AOX', 'Nitrogen - as total N',
#        'Phosphorus - as total P', 'Total organic carbon (TOC)', 'Arsenic',
# ...

# %%
data = df[df['ABOVE_THRESHOLD_(kg)'] > 0]['SUBSTANCE_NAME'][df['YEAR']==2020].value_counts()
data.plot(kind='bar',figsize=(16, 10))
# Out:
# <AxesSubplot:>

# %%
data = df[df['ABOVE_THRESHOLD_(kg)'] > 0]['SUBSTANCE_NAME'].value_counts()
data.plot(kind='bar',figsize=(16, 10))
# Out:
# <AxesSubplot:>

# %%
def PropByVar(df, variable):
    dataframe = df[variable].value_counts()
    ax = dataframe.plot.bar(figsize=(30,10), fontsize = 15)
    ax.set_title(variable + '\n' , fontsize = 15)
    return n.round(dataframe/df.shape[0]*100,2)
PropByVar(df,'SUBSTANCE_NAME')
# Out:
# Nitrogen oxides (NO and NO2) as NO2               5.05
# Ammonia                                           4.92
# Particulate matter - PM10                         4.74
# Carbon dioxide                                    3.66
# Methane                                           3.20
#                                                   ...
# Phosphorus                                        0.00
# Nitrogen oxides (only for LCPD reporting unit)    0.00
# Hydrogen chloride                                 0.00
# Hydrocarbons - total nos                          0.00
# Nitrogen oxides (as NO2)                          0.00
# Name: SUBSTANCE_NAME, Length: 111, dtype: float64

# %%
def PropByVar(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(10,10), autopct='%1.2f%%' , fontsize = 12)
    ax.set_title(variable + '\n' , fontsize = 15)
    return n.round(dataframe_pie/df.shape[0]*100,2)
PropByVar(df,'EA_AREA_NAME')
# Out:
# Yorkshire                                                      11.01
# Greater Manchester Merseyside and Cheshire                      9.90
# West Midlands                                                   8.93
# Lincolnshire and Northamptonshire                               8.52
# East Anglia                                                     6.85
# Cumbria and Lancashire                                          6.59
# Wessex                                                          4.90
# Hertfordshire and North London                                  4.70
# Solent and South Downs                                          4.42
# North East                                                      3.95
# East Midlands                                                   3.57
# Staffordshire Warwickshire and West Midlands                    3.22
# Kent, South London and East Sussex                              2.82
# Northumberland Durham and Tees                                  2.82
# ...
